# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/lingelizabeth/BWSIfinal/blob/master/mat_to_csv.ipynb)

# %%
from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
files.upload()
# Out:
#      <input type="file" id="files-8e7471ac-b533-4b84-a714-f196ce9f3683" name="files[]" multiple disabled />
#      <output id="result-8e7471ac-b533-4b84-a714-f196ce9f3683">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving A00001.mat to A00001.mat
# ...

# %%
import scipy.io
import numpy as np

data = scipy.io.loadmat("A00001.mat")
newfile = open("A00001.csv", 'w+')


for i in data:
  if '__' not in i and 'readme' not in i:
    np.savetxt(("A00001"+i+".csv"),data[i],delimiter=',')
    print(i)
# Out:
# val

# %%
! ls
import os
os.getcwd()
# Out:
# A00001.csv  A00001.mat	A00001val.csv  datalab
# '/content'

# %%
files.download('A00001val.csv')
